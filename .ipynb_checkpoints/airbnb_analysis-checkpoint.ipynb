# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load and preview the Airbnb listings raw data
df = pd.read_csv('listings.csv')
df.head()
# Out:
#      id                                               name  host_id host_name  \
# 0  3362  Convention Center Rowhouse & In Law: 2 Units, 4BR     2798      Ayeh
# 1  3662                                 Vita's Hideaway II     4645      Vita
# 2  3686                                    Vita's Hideaway     4645      Vita
# 3  3771                                       Mt. Pleasant     4795  Charlene
# 4  4002       2 Bedroom Private Condo Suite (Basement Apt)     5143   Anthony
#
#    neighbourhood_group                                      neighbourhood  \
# 0                  NaN                                 Shaw, Logan Circle
# 1                  NaN                                 Historic Anacostia
# 2                  NaN                                 Historic Anacostia
# 3                  NaN  Columbia Heights, Mt. Pleasant, Pleasant Plain...
# 4                  NaN  North Michigan Park, Michigan Park, University...
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0  38.910461 -77.019331  Entire home/apt    433               2
# 1  38.861925 -76.989634     Private room     65               2
# 2  38.863138 -76.988362     Private room     55               2
# 3  38.927605 -77.039265     Private room     88               1
# 4  38.940084 -76.989360  Entire home/apt    120               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                150  2018-09-21               1.27
# 1                 35  2018-06-02               0.38
# 2                 67  2017-10-29               0.69
# 3                  1  2009-01-21               0.01
# 4                148  2018-08-03               1.25
#
#    calculated_host_listings_count  availability_365
# 0                               5               324
# 1                               3               364
# 2                               3               365
# 3                               1                 0
# 4                               1               361

# %%
#Select relevant columns to keep in the dataframe
reviews_df = df[['neighbourhood', 'number_of_reviews']]
reviews_df.head()
# Out:
#                                        neighbourhood  number_of_reviews
# 0                                 Shaw, Logan Circle                150
# 1                                 Historic Anacostia                 35
# 2                                 Historic Anacostia                 67
# 3  Columbia Heights, Mt. Pleasant, Pleasant Plain...                  1
# 4  North Michigan Park, Michigan Park, University...                148

# %%
#Group by neighbourhood to get total number of reviews for each
neighbourhood_df = reviews_df.groupby(reviews_df['neighbourhood']).sum().reset_index()
neighbourhood_df.head()
# Out:
#                                      neighbourhood  number_of_reviews
# 0             Brightwood Park, Crestwood, Petworth              13429
# 1                    Brookland, Brentwood, Langdon               5337
# 2                       Capitol Hill, Lincoln Park              31095
# 3  Capitol View, Marshall Heights, Benning Heights               1607
# 4   Cathedral Heights, McLean Gardens, Glover Park               2650

# %%
#Normalize the values for each neighbourhood. Divide by total and multiply by 1000
neighbourhood_df['normalized value (per 1000 reviews)'] = (neighbourhood_df['number_of_reviews']/neighbourhood_df['number_of_reviews'].sum() * 1000).round(0)
neighbourhood_df.head()
# Out:
#                                      neighbourhood  number_of_reviews  \
# 0             Brightwood Park, Crestwood, Petworth              13429
# 1                    Brookland, Brentwood, Langdon               5337
# 2                       Capitol Hill, Lincoln Park              31095
# 3  Capitol View, Marshall Heights, Benning Heights               1607
# 4   Cathedral Heights, McLean Gardens, Glover Park               2650
#
#    normalized value (per 1000 reviews)
# 0                                 48.0
# 1                                 19.0
# 2                                112.0
# 3                                  6.0
# 4                                 10.0

# %%
#Plot histogram to show the spread and shape of the data

plt.figure(figsize=(15,15))

# Show 4 different binwidths
for i, binwidth in enumerate([1, 5, 10, 20]):
    
    # Set up the plots
    ax = plt.subplot(2, 2, i + 1)
    
    # Draw the plots
    ax.hist(neighbourhood_df['normalized value (per 1000 reviews)'], bins = int(120/binwidth),
             color = 'blue', edgecolor = 'black')
    
    # Title and labels
    ax.set_title('Histogram with Binwidth = %d' % binwidth, size = 15)
    ax.set_xlabel('Number Of Reviews', size = 12)
    ax.set_ylabel('Listings', size= 12)

plt.show()

# %%
grouped_df.to_csv('cleaned_reviews_dc.csv')
